# %%
pip install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.org/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = "aff02990067f42eb861043936d9cda3c", client_secret = "ae05a872524f45ff87ea705e0d9c5a3b")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/6VOedaf3eNWDOVpa9Qdlvg?si=4Aq3dgn_SEuePcKeTubSKA"

# %%
playlist_URI = playlist_link.split('/')[-1].split('?')[0]

# %% [markdown]
# ### getting data that is needed for creating a dataframe for our pipeline

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
len(data['items'])
# Out:
# 95

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6xUYw5goKIoyJQi9C27UBy'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'NUNCA MUDA?'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-01-09'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 6

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'

# %% [markdown]
# ### iterating through all the data that is available in the playlist

# %%
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name  = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    ## creating a dictionary using the data values that we have got from iterating
    album_element = {'album_id':album_id, 'name': album_name, 'release_date':album_release_date
                     ,'total_tracks': album_total_tracks, 'url':album_url
                    }
    # creating a list for more structured data
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '6xUYw5goKIoyJQi9C27UBy',
#   'name': 'NUNCA MUDA?',
#   'release_date': '2025-01-09',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'},
#  {'album_id': '4s7LxMlh6RxgdMhldfMe8u',
#   'name': 'Funk de Beleza',
#   'release_date': '2024-10-04',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4s7LxMlh6RxgdMhldfMe8u'},
#  {'album_id': '5D17Gk0J7jPXLvWMszqijF',
#   'name': 'MONTAGEM TOMADA',
#   'release_date': '2025-03-21',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/5D17Gk0J7jPXLvWMszqijF'},
#  {'album_id': '6dNugoBYWvUDQDtLurImhw',
#   'name': 'X-TALI',
#   'release_date': '2024-08-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6dNugoBYWvUDQDtLurImhw'},
#  {'album_id': '0XoyJmD8cp3L8ixHoW3lB6',
#   'name': 'MONTAGEM CONTIGO',
#   'release_date': '2025-04-04',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/0XoyJmD8cp3L8ixHoW3lB6'},
# ...

# %%
artist_list = []
for row in data['items']:
    for key , value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artist_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artist_id': '7lAaAGxYxk2GH8cMbTEwAL',
#   'artist_name': 'NXGHT!',
#   'external_url': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL'},
#  {'artist_id': '14hsjenLEdvafsGkk2CEiF',
#   'artist_name': 'MC Fabinho da Osk',
#   'external_url': 'https://api.spotify.com/v1/artists/14hsjenLEdvafsGkk2CEiF'},
#  {'artist_id': '3g0UoyvaTaHUrfpHiRqsD1',
#   'artist_name': 'Nateki',
#   'external_url': 'https://api.spotify.com/v1/artists/3g0UoyvaTaHUrfpHiRqsD1'},
#  {'artist_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artist_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artist_id': '10mKIVPFtg42JIvttHQrzr',
#   'artist_name': 'MC MAYAH',
#   'external_url': 'https://api.spotify.com/v1/artists/10mKIVPFtg42JIvttHQrzr'},
#  {'artist_id': '7kk9ucvRJim0NMM89Lml2Y',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = { 'song_id' :song_id, 'song_name': song_name, 'duration_ms':song_duration, 'url': song_url,
                      'popularity':song_popularity, 'song_added':song_added, 'album_id': album_id, 'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
# Album Data Frame

album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id              name release_date  total_tracks  \
# 0  6xUYw5goKIoyJQi9C27UBy       NUNCA MUDA?   2025-01-09             6
# 1  4s7LxMlh6RxgdMhldfMe8u    Funk de Beleza   2024-10-04             3
# 2  5D17Gk0J7jPXLvWMszqijF   MONTAGEM TOMADA   2025-03-21             4
# 3  6dNugoBYWvUDQDtLurImhw            X-TALI   2024-08-23             1
# 4  0XoyJmD8cp3L8ixHoW3lB6  MONTAGEM CONTIGO   2025-04-04             4
#
#                                                  url
# 0  https://open.spotify.com/album/6xUYw5goKIoyJQi...
# 1  https://open.spotify.com/album/4s7LxMlh6RxgdMh...
# 2  https://open.spotify.com/album/5D17Gk0J7jPXLvW...
# 3  https://open.spotify.com/album/6dNugoBYWvUDQDt...
# 4  https://open.spotify.com/album/0XoyJmD8cp3L8ix...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      95 non-null     object
#  1   name          95 non-null     object
#  2   release_date  95 non-null     object
#  3   total_tracks  95 non-null     int64
#  4   url           95 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ KB

# %%
album_df = album_df.drop_duplicates(subset =['album_id'])

# %%
## artist Dataframe
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  5dDNNq04RjKXFOADdHd6VX        Scythermane
# 1  7lAaAGxYxk2GH8cMbTEwAL             NXGHT!
# 2  14hsjenLEdvafsGkk2CEiF  MC Fabinho da Osk
# 3  3g0UoyvaTaHUrfpHiRqsD1             Nateki
# 4  5dDNNq04RjKXFOADdHd6VX        Scythermane
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5dDNNq04RjK...
# 1  https://api.spotify.com/v1/artists/7lAaAGxYxk2...
# 2  https://api.spotify.com/v1/artists/14hsjenLEdv...
# 3  https://api.spotify.com/v1/artists/3g0UoyvaTaH...
# 4  https://api.spotify.com/v1/artists/5dDNNq04RjK...

# %%
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])

# %%
# Song Data Frame

song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                 song_name  duration_ms  \
# 0  5EIjpM1B1VsLoKvv2iwd0P               NUNCA MUDA?        81500
# 1  43jExF2HeZ6cJIGrWF0ie4   Funk de Beleza - Slowed       145115
# 2  1mfvWzF39LwVpAm8g0LhQT  MONTAGEM TOMADA - Slowed        84901
# 3  6yIkBXij6NSjmRGRpQupqO                    X-TALI        72352
# 4  38eZ1H5Mpr4YanTn5kY8JD          MONTAGEM CONTIGO        96808
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5EIjpM1B1VsLoKv...          86
# 1  https://open.spotify.com/track/43jExF2HeZ6cJIG...          86
# 2  https://open.spotify.com/track/1mfvWzF39LwVpAm...          71
# 3  https://open.spotify.com/track/6yIkBXij6NSjmRG...          74
# 4  https://open.spotify.com/track/38eZ1H5Mpr4YanT...          71
#
#              song_added                album_id               artist_id
# 0  2025-03-07T07:49:17Z  6xUYw5goKIoyJQi9C27UBy  5dDNNq04RjKXFOADdHd6VX
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      95 non-null     object
#  1   name          95 non-null     object
#  2   release_date  95 non-null     datetime64[ns]
#  3   total_tracks  95 non-null     int64
#  4   url           95 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      95 non-null     object
#  1   song_name    95 non-null     object
#  2   duration_ms  95 non-null     int64
#  3   url          95 non-null     object
#  4   popularity   95 non-null     int64
#  5   song_added   95 non-null     datetime64[ns, UTC]
#  6   album_id     95 non-null     object
#  7   artist_id    95 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.1+ KB
